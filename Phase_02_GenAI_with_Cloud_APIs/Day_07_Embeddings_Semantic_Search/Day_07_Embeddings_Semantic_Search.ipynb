# %%
# !pip install chromadb sentence-transformers -q
print("Successful installed")
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-llms-openai-like 0.5.3 requires transformers<5,>=4.37.0, but you have transformers 5.9.0 which is incompatible.
# Successful installed

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb


print("All libaries imported successfully")
print(f"Chromadb version: {chromadb.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# All libaries imported successfully
# Chromadb version: 1.5.9
# Pandas version: 2.2.2

# %%
documents = [
    "I like apples",
    "I like oranges",
    "I like bananas",
    "I do not like junk food",
    "I like natural foods"
]

query_keyword = "natural foods"

for i, doc in enumerate(documents):
    if query_keyword.lower() in doc.lower():
      print(f"    FOUND [doc_{i}]: {doc}")
    else:
      print(f"    MISSED [doc_{i}]: {doc}")
# Out:
#     MISSED [doc_0]: I like apples
#     MISSED [doc_1]: I like oranges
#     MISSED [doc_2]: I like bananas
#     MISSED [doc_3]: I do not like junk food
#     FOUND [doc_4]: I like natural foods
